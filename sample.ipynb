# %%
# !ipython --version
# Out:
# ~~~~~~~~~~~~
# ...

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
import numpy as np
from numpy import  pi, sin, cos

# %%
# %matplotlib inline

# %%
x = np.linspace(-pi, 3*pi, 400)
plt.plot(x, sin(x))
plt.plot(x, cos(x))
plt.title('最初のグラフ')
plt.show()
